# %%
import pandas as pd
import numpy as np
Laliga= pd.read_csv("Laliga.csv")

# %%
Laliga.head(10)
# Out:
#            Unnamed: 0       Unnamed: 1 Unnamed: 2 Unnamed: 3   Unnamed: 4  \
# Unnamed: 0
# Pos               Pos             Team    Seasons     Points  GamesPlayed
# 1                   1      Real Madrid         86       4385         2762
# 2                   2        Barcelona         86       4262         2762
# 3                   3  Atletico Madrid         80       3442         2614
# 4                   4         Valencia         82       3386         2664
# 5                   5  Athletic Bilbao         86       3368         2762
# 6                   6          Sevilla         73       2819         2408
# 7                   7         Espanyol         82       2792         2626
# 8                   8    Real Sociedad         70       2573         2302
# 9                   9         Zaragoza         58       2109         1986
#
#            Unnamed: 5  Unnamed: 6 Unnamed: 7 Unnamed: 8    Unnamed: 9  \
# Unnamed: 0
# ...

# %%
Laliga.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62 entries, Pos to 61
# Data columns (total 20 columns):
# Unnamed: 0     62 non-null object
# Unnamed: 1     62 non-null object
# Unnamed: 2     62 non-null object
# Unnamed: 3     62 non-null object
# Unnamed: 4     62 non-null object
# Unnamed: 5     62 non-null object
# Unnamed: 6     62 non-null object
# Unnamed: 7     62 non-null object
# Unnamed: 8     62 non-null object
# Unnamed: 9     62 non-null object
# Unnamed: 10    62 non-null object
# Unnamed: 11    62 non-null object
# Unnamed: 12    62 non-null object
# Unnamed: 13    62 non-null object
# Unnamed: 14    62 non-null object
# Unnamed: 15    62 non-null object
# Unnamed: 16    62 non-null object
# Unnamed: 17    62 non-null object
# Unnamed: 18    62 non-null object
# Unnamed: 19    62 non-null object
# dtypes: object(20)
# memory usage: 10.2+ KB

# %%
##replace - with 0
Laliga1=Laliga.replace(to_replace ="-", 
                 value ="0")
##Laliga.replace('-', 0)

# %%
Laliga1
# Out:
#            Unnamed: 0           Unnamed: 1 Unnamed: 2 Unnamed: 3   Unnamed: 4  \
# Unnamed: 0
# Pos               Pos                 Team    Seasons     Points  GamesPlayed
# 1                   1          Real Madrid         86       4385         2762
# 2                   2            Barcelona         86       4262         2762
# 3                   3      Atletico Madrid         80       3442         2614
# 4                   4             Valencia         82       3386         2664
# 5                   5      Athletic Bilbao         86       3368         2762
# 6                   6              Sevilla         73       2819         2408
# 7                   7             Espanyol         82       2792         2626
# 8                   8        Real Sociedad         70       2573         2302
# 9                   9             Zaragoza         58       2109         1986
# 10                 10           Real Betis         51       1884         1728
# ...

# %%
Laliga1.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19'],
#       dtype='object')

# %%
Laliga1.head(10)
# Out:
#            Unnamed: 0       Unnamed: 1 Unnamed: 2 Unnamed: 3   Unnamed: 4  \
# Unnamed: 0
# Pos               Pos             Team    Seasons     Points  GamesPlayed
# 1                   1      Real Madrid         86       4385         2762
# 2                   2        Barcelona         86       4262         2762
# 3                   3  Atletico Madrid         80       3442         2614
# 4                   4         Valencia         82       3386         2664
# 5                   5  Athletic Bilbao         86       3368         2762
# 6                   6          Sevilla         73       2819         2408
# 7                   7         Espanyol         82       2792         2626
# 8                   8    Real Sociedad         70       2573         2302
# 9                   9         Zaragoza         58       2109         1986
#
#            Unnamed: 5  Unnamed: 6 Unnamed: 7 Unnamed: 8    Unnamed: 9  \
# Unnamed: 0
# ...

# %%
Laliga1.rename(columns={'Unnamed: 0' : 'Pos',
                    'Unnamed: 1'  : 'Team',
                     'Unnamed: 2' : 'Season',
                     'Unnamed: 3'    : 'Points',
                     'Unnamed: 4'     : 'GamesPlayed',
                     'Unnamed: 5'    :  'GamesWon',
                     'Unnamed: 6'   :  'GamesDrawn' ,
                    'Unnamed: 7' : 'GamesLost',
                    'Unnamed: 8'  : 'GoalsFor',
                     'Unnamed: 9' : 'GoalsAgainst',
                     'Unnamed: 10'    : 'Champion',
                     'Unnamed: 11'     : 'Runner-up',
                     'Unnamed: 12'    :  'Third',
                     'Unnamed: 13'   :  'Fourth',
                      'Unnamed: 14'     : 'Fifth',
                     'Unnamed: 15'    :  'Sixth',
                     'Unnamed: 16'   :  'T' ,
                    'Unnamed: 17' : 'Debut',
                    'Unnamed: 18'  : 'Since/LastApp',
                     'Unnamed: 19' : 'BestPosition'}, 
                 inplace=True)

# %%
Laliga1.columns
# Out:
# Index(['Pos', 'Team', 'Season', 'Points', 'GamesPlayed', 'GamesWon',
#        'GamesDrawn', 'GamesLost', 'GoalsFor', 'GoalsAgainst', 'Champion',
#        'Runner-up', 'Third', 'Fourth', 'Fifth', 'Sixth', 'T', 'Debut',
#        'Since/LastApp', 'BestPosition'],
#       dtype='object')

# %%
##print(Laliga1[(Laliga1['Debut']>='1930') & (Laliga1['Debut'] < =1981)].head())
Laliga2= Laliga1[Laliga1['Debut'] >='1930']
##Laliga1[Laliga1['Debut'] <='1980']

# %%
##Print all the teams which have started playing between 1930-1980.
Laliga3= Laliga2.loc[Laliga2['Debut'] <='1980', ['Team']]

# %%
Laliga3
# Out:
#                            Team
# Unnamed: 0
# 4                      Valencia
# 6                       Sevilla
# 9                      Zaragoza
# 10                   Real Betis
# 11          Deportivo La Coruna
# 12                   Celta Vigo
# 13                   Valladolid
# 15               Sporting Gijon
# 16                      Osasuna
# 17                       Malaga
# 18                       Oviedo
# 19                     Mallorca
# 20                   Las Palmas
# 22                      Granada
# 23               Rayo Vallecano
# 24                        Elche
# 26                     Hercules
# 27                     Tenerife
# 28                       Murcia
# 29                       Alaves
# 30                      Levante
# 31                    Salamanca
# 32                     Sabadell
# 33                        Cadiz
# 35                    Castellon
# 38                      Cordoba
# 40                   Recreativo
# 41                    Burgos CF
# ...

# %%
Laliga3.shape
# Out:
# (37, 20)

# %%
Laliga1 = Laliga1.drop("Pos", axis=0)

# %%
Laliga1.Points=Laliga1.Points.astype(int)

# %%
Laliga1.dtypes
# Out:
# Pos              object
# Team             object
# Season           object
# Points            int64
# GamesPlayed      object
# GamesWon         object
# GamesDrawn       object
# GamesLost        object
# GoalsFor         object
# GoalsAgainst     object
# Champion         object
# Runner-up        object
# Third            object
# Fourth           object
# Fifth            object
# Sixth            object
# T                object
# Debut            object
# Since/LastApp    object
# BestPosition     object
# dtype: object

# %%
## Print the list of teams which came Top 5 in terms of point
Laliga1.sort_values(by=['Points'],ascending=False).head(5)
# Out:
#            Pos             Team Season  Points GamesPlayed GamesWon  \
# Unnamed: 0
# 1            1      Real Madrid     86    4385        2762     1647
# 2            2        Barcelona     86    4262        2762     1581
# 3            3  Atletico Madrid     80    3442        2614     1241
# 4            4         Valencia     82    3386        2664     1187
# 5            5  Athletic Bilbao     86    3368        2762     1209
#
#            GamesDrawn GamesLost GoalsFor GoalsAgainst Champion Runner-up  \
# Unnamed: 0
# 1                 552       563     5947         3140       33        23
# 2                 573       608     5900         3114       25        25
# 3                 598       775     4534         3309       10         8
# 4                 616       861     4398         3469        6         6
# 5                 633       920     4631         3700        8         7
#
#            Third Fourth Fifth Sixth   T    Debut Since/LastApp BestPosition
# Unnamed: 0
# ...

# %%
Laliga1.GoalsFor=Laliga1.GoalsFor.astype(int)
Laliga1.GoalsAgainst=Laliga1.GoalsAgainst.astype(int)

# %%
Laliga1.dtypes
# Out:
# Pos              object
# Team             object
# Season           object
# Points            int64
# GamesPlayed      object
# GamesWon         object
# GamesDrawn       object
# GamesLost        object
# GoalsFor          int64
# GoalsAgainst      int64
# Champion         object
# Runner-up        object
# Third            object
# Fourth           object
# Fifth            object
# Sixth            object
# T                object
# Debut            object
# Since/LastApp    object
# BestPosition     object
# dtype: object

# %%
##Laliga1['Goal_diff_count']= Laliga1["GoalsFor"]- Laliga1["GoalsAgainst"]
##Laliga1.(columns=lambda x: x[0:3], inplace=False).head()
##def Goal_diff_count(GoalsFor, GoalsFor)
##print (Laliga1["GoalsFor"]- Laliga1["GoalsAgainst"])
    
def Goal_diff_count(GoalsFor, GoalsAgainst):
    Laliga1['Goal_diff_count']= GoalsFor - GoalsAgainst
Goal_diff_count (Laliga1["GoalsFor"], Laliga1["GoalsAgainst"])
Laliga1[['Team','Goal_diff_count']]
# Out:
#                            Team  Goal_diff_count
# Unnamed: 0
# 1                   Real Madrid             2807
# 2                     Barcelona             2786
# 3               Atletico Madrid             1225
# 4                      Valencia              929
# 5               Athletic Bilbao              931
# 6                       Sevilla              307
# 7                      Espanyol             -280
# 8                 Real Sociedad               -2
# 9                      Zaragoza             -164
# 10                   Real Betis             -333
# 11          Deportivo La Coruna             -136
# 12                   Celta Vigo             -346
# 13                   Valladolid             -413
# 14             Racing Santander             -525
# 15               Sporting Gijon             -399
# 16                      Osasuna             -334
# 17                       Malaga             -342
# 18                       Oviedo             -309
# ...

# %%
Laliga1['Goal_diff_count']= abs(Laliga1['Goal_diff_count'])

# %%
##maximum goal difference
Laliga1.sort_values(by=['Goal_diff_count'],ascending=False).head(1)
# Out:
#            Pos         Team Season  Points GamesPlayed GamesWon GamesDrawn  \
# Unnamed: 0
# 1            1  Real Madrid     86    4385        2762     1647        552
#
#            GamesLost  GoalsFor  GoalsAgainst       ...       Runner-up Third  \
# Unnamed: 0                                         ...
# 1                563      5947          3140       ...              23     8
#
#            Fourth Fifth Sixth   T Debut Since/LastApp BestPosition  \
# Unnamed: 0
# 1               8     3     4  79  1929          1929            1
#
#            Goal_diff_count
# Unnamed: 0
# 1                     2807
#
# [1 rows x 21 columns]

# %%
##minimum goal difference
Laliga1.sort_values(by=['Goal_diff_count'],ascending=True).head(1)
# Out:
#            Pos    Team Season  Points GamesPlayed GamesWon GamesDrawn  \
# Unnamed: 0
# 61          61  Girona      1       0           0        0          0
#
#            GamesLost  GoalsFor  GoalsAgainst       ...       Runner-up Third  \
# Unnamed: 0                                         ...
# 61                 0         0             0       ...               0     0
#
#            Fourth Fifth Sixth  T    Debut Since/LastApp BestPosition  \
# Unnamed: 0
# 61              0     0     0  0  2017-18       2017-18            9
#
#            Goal_diff_count
# Unnamed: 0
# 61                       0
#
# [1 rows x 21 columns]

# %%
##min goal diff
Laliga1.sort_values(by=['Goal_diff_count'],ascending=True).head(1)
# Out:
#            Pos    Team Season  Points  GamesPlayed  GamesWon GamesDrawn  \
# Unnamed: 0
# 61          61  Girona      1       0            0         0          0
#
#            GamesLost  GoalsFor  GoalsAgainst       ...       Third Fourth  \
# Unnamed: 0                                         ...
# 61                 0         0             0       ...           0      0
#
#            Fifth Sixth  T    Debut Since/LastApp BestPopsition  \
# Unnamed: 0
# 61             0     0  0  2017-18       2017-18             9
#
#            Goal_diff_count Winning Percent
# Unnamed: 0
# 61                       0             NaN
#
# [1 rows x 22 columns]

# %%
Laliga1.GamesWon=Laliga1.GamesWon.astype(int)
Laliga1.GamesPlayed=Laliga1.GamesPlayed.astype(int)

# %%
Laliga1.dtypes
# Out:
# Pos                object
# Team               object
# Season             object
# Points              int64
# GamesPlayed         int64
# GamesWon            int64
# GamesDrawn         object
# GamesLost          object
# GoalsFor            int64
# GoalsAgainst        int64
# Champion           object
# Runner-up          object
# Third              object
# Fourth             object
# Fifth              object
# Sixth              object
# T                  object
# Debut              object
# Since/LastApp      object
# BestPosition       object
# Goal_diff_count     int64
# dtype: object

# %%
Laliga1['Winning Percent']= (Laliga1["GamesWon"]/ Laliga1["GamesPlayed"])*100

# %%
Laliga1.fillna(0)
# Out:
#            Pos                 Team Season  Points  GamesPlayed  GamesWon  \
# Unnamed: 0
# 1            1          Real Madrid     86    4385         2762      1647
# 2            2            Barcelona     86    4262         2762      1581
# 3            3      Atletico Madrid     80    3442         2614      1241
# 4            4             Valencia     82    3386         2664      1187
# 5            5      Athletic Bilbao     86    3368         2762      1209
# 6            6              Sevilla     73    2819         2408       990
# 7            7             Espanyol     82    2792         2626       948
# 8            8        Real Sociedad     70    2573         2302       864
# 9            9             Zaragoza     58    2109         1986       698
# 10          10           Real Betis     51    1884         1728       606
# 11          11  Deportivo La Coruna     45    1814         1530       563
# ...

# %%
Laliga1.sort_values(by=['Winning Percent'],ascending=False).head(5)
# Out:
#            Pos             Team Season  Points  GamesPlayed  GamesWon  \
# Unnamed: 0
# 1            1      Real Madrid     86    4385            1      1647
# 2            2        Barcelona     86    4262            1      1581
# 3            3  Atletico Madrid     80    3442            1      1241
# 4            4         Valencia     82    3386            1      1187
# 5            5  Athletic Bilbao     86    3368            1      1209
#
#            GamesDrawn GamesLost  GoalsFor  GoalsAgainst       ...       Third  \
# Unnamed: 0                                                    ...
# 1                 552       563      5947          3140       ...           8
# 2                 573       608      5900          3114       ...          12
# 3                 598       775      4534          3309       ...          16
# 4                 616       861      4398          3469       ...          10
# ...

# %%
Laliga1.BestPosition=Laliga1.BestPosition.astype(int)
##Laliga1.dtypes

# %%
Laliga1.dtypes
# Out:
# Pos                 object
# Team                object
# Season              object
# Points               int64
# GamesPlayed          int64
# GamesWon             int64
# GamesDrawn          object
# GamesLost           object
# GoalsFor             int64
# GoalsAgainst         int64
# Champion            object
# Runner-up           object
# Third               object
# Fourth              object
# Fifth               object
# Sixth               object
# T                   object
# Debut               object
# Since/LastApp       object
# BestPosition         int64
# Goal_diff_count      int64
# Winning Percent    float64
# dtype: object

# %%
Laliga5=Laliga1.groupby('BestPosition').first()

# %%
Laliga5
# Out:
#              Pos              Team Season  Points  GamesPlayed  GamesWon  \
# BestPosition
# 1              1       Real Madrid     86    4385         2762      1647
# 2              9          Zaragoza     58    2109         1986       698
# 3              7          Espanyol     82    2792         2626       948
# 4             12        Celta Vigo     51    1789         1698       586
# 5             24             Elche     21     606          678       203
# 6             22           Granada     23     667          742       218
# 7             31         Salamanca     12     375          423       123
# 8             23    Rayo Vallecano     17     662          652       189
# 9             46       Real Burgos      3      96          114        26
# 10            39        Compostela      4     190          160        52
# 11            28            Murcia     18     445          586       145
# 12            33             Cadiz     12     343          448       104
# ...

# %%
Laliga1['BestPosition'].value_counts()
# Out:
# 1     9
# 4     6
# 7     5
# 2     5
# 6     5
# 3     4
# 5     4
# 10    4
# 8     4
# 17    3
# 16    3
# 9     2
# 12    2
# 19    1
# 11    1
# 14    1
# 15    1
# 20    1
# Name: BestPosition, dtype: int64

# %%
Laliga5
# Out:
#              Pos              Team Season  Points  GamesPlayed  GamesWon  \
# BestPosition
# 1              1       Real Madrid     86    4385         2762      1647
# 2              9          Zaragoza     58    2109         1986       698
# 3              7          Espanyol     82    2792         2626       948
# 4             12        Celta Vigo     51    1789         1698       586
# 5             24             Elche     21     606          678       203
# 6             22           Granada     23     667          742       218
# 7             31         Salamanca     12     375          423       123
# 8             23    Rayo Vallecano     17     662          652       189
# 9             46       Real Burgos      3      96          114        26
# 10            39        Compostela      4     190          160        52
# 11            28            Murcia     18     445          586       145
# 12            33             Cadiz     12     343          448       104
# ...

# %%
Laligaunique=Laliga1['Team'].unique

# %%
Laligaunique
# Out:
# <bound method Series.unique of Unnamed: 0
# 1             Real Madrid
# 2               Barcelona
# 3         Atletico Madrid
# 4                Valencia
# 5         Athletic Bilbao
# 6                 Sevilla
# 7                Espanyol
# 8           Real Sociedad
# 9                Zaragoza
# 10             Real Betis
# 11    Deportivo La Coruna
# 12             Celta Vigo
# 13             Valladolid
# 14       Racing Santander
# 15         Sporting Gijon
# 16                Osasuna
# 17                 Malaga
# 18                 Oviedo
# 19               Mallorca
# 20             Las Palmas
# 21             Villarreal
# 22                Granada
# 23         Rayo Vallecano
# 24                  Elche
# 25                 Getafe
# 26               Hercules
# 27               Tenerife
# 28                 Murcia
# 29                 Alaves
# 30                Levante
#              ...
# 32               Sabadell
# 33                  Cadiz
# 34               Logrones
# ...

# %%
for i in Laligaunique:
   Laliga[i]=
